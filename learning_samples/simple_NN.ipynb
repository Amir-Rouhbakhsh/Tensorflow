# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ### Data Definition

# %%
x= tf.constant([-1, -2, 0, 1, 4, 5 ,8],dtype=float)
y= x*3 -5

# %%
x.numpy()
# Out:
# array([-1., -2.,  0.,  1.,  4.,  5.,  8.], dtype=float32)

# %%
y.numpy()
# Out:
# array([ -8., -11.,  -5.,  -2.,   7.,  10.,  19.], dtype=float32)

# %%
model= keras.Sequential([keras.layers.Dense(units=1, activation=None, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_1 (Dense)             (None, 1)                 2
#
# ...
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(x, y, batch_size=1, epochs=500)
# Out:
# Epoch 1/500
# 7/7 [==============================] - 2s 4ms/step - loss: 29.6789
# Epoch 2/500
# 7/7 [==============================] - 0s 3ms/step - loss: 15.9282
# Epoch 3/500
# 7/7 [==============================] - 0s 3ms/step - loss: 12.8226
# Epoch 4/500
# 7/7 [==============================] - 0s 3ms/step - loss: 10.1558
# Epoch 5/500
# 7/7 [==============================] - 0s 3ms/step - loss: 8.7182
# Epoch 6/500
# 7/7 [==============================] - 0s 4ms/step - loss: 6.9356
# Epoch 7/500
# 7/7 [==============================] - 0s 4ms/step - loss: 5.7726
# Epoch 8/500
# 7/7 [==============================] - 0s 3ms/step - loss: 4.6156
# Epoch 9/500
# 7/7 [==============================] - 0s 4ms/step - loss: 3.7748
# Epoch 10/500
# 7/7 [==============================] - 0s 3ms/step - loss: 3.1940
# Epoch 11/500
# 7/7 [==============================] - 0s 4ms/step - loss: 2.5345
# Epoch 12/500
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0867
# ...

# %% [markdown]
# test

# %%
x_test=tf.constant([-2,7,20],dtype=float)
y_test=x_test*3-5
print(x_test.numpy())
print(y_test.numpy())
# Out:
# [-2.  7. 20.]
# [-11.  16.  55.]

# %% [markdown]
# predict

# %%
y_pred= model.predict(x_test)
y_pred
# Out:
# 1/1 [==============================] - 0s 17ms/step
# array([[-10.999991],
#        [ 16.000006],
#        [ 55.000004]], dtype=float32)

# %%
import matplotlib.pyplot as plt

plt.scatter(x_test.numpy(), y_test.numpy(), color='blue', linewidths= 8)
plt.scatter(x_test.numpy(), y_pred, color='red', linewidth=2 )
